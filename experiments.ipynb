# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from src.model.inference import get_nn_predictions
from src.training.evaluate import evaluate
from src.utils.config import load_config

# %%
config = load_config()
X_train = np.load("data/splits/baseline/X_train.npy")
y_train = np.load("data/splits/baseline/y_train.npy")
X_test = np.load("data/splits/baseline/X_test.npy")
y_test = np.load("data/splits/baseline/y_test.npy")

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
lr_probs = lr.predict_proba(X_test)[:,1]
lr_metrics = evaluate(lr_probs, y_test)
print(lr_metrics)
# Out:
# {'accuracy': 0.7313432835820896, 'auc': 0.8373802628647806, 'loss': 0.5000710074165925}

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_probs = rf.predict_proba(X_test)[:, 1]
rf_metrics = evaluate(rf_probs, y_test)
print(rf_metrics)
# Out:
# {'accuracy': 0.7611940298507462, 'auc': 0.8134328358208955, 'loss': 0.5504137480568482}

# %%
svm = SVC(probability=True, random_state=42)
svm.fit(X_train, y_train)
svm_probs = svm.predict_proba(X_test)[:, 1]
svm_metrics = evaluate(svm_probs, y_test)
print(svm_metrics)
# Out:
# {'accuracy': 0.746268656716418, 'auc': 0.8046335486745378, 'loss': 0.5459165521449134}

# %%
nn_probs = get_nn_predictions(config, X_test)
nn_metrics = evaluate(nn_probs, y_test)
print(nn_metrics)
# Out:
# {'accuracy': 0.7238805970149254, 'auc': 0.8300289596792157, 'loss': 0.5031788743951708}

# %%
print(f'lr: {lr_metrics}, rf: {rf_metrics}, svm: {svm_metrics},  nn: {nn_metrics}')
# Out:
# lr: {'accuracy': 0.7313432835820896, 'auc': 0.8373802628647806, 'loss': 0.5000710074165925}, rf: {'accuracy': 0.7611940298507462, 'auc': 0.8134328358208955, 'loss': 0.5504137480568482}, svm: {'accuracy': 0.746268656716418, 'auc': 0.8046335486745378, 'loss': 0.5459165521449134},  nn: {'accuracy': 0.7238805970149254, 'auc': 0.8300289596792157, 'loss': 0.5031788743951708}

# %%
seed_preds = (X_test[:, -1] < 0).astype(int)
accuracy = float(np.mean(seed_preds == y_test))
print(accuracy)
# Out:
# 0.7835820895522388

# %%
colley_config = load_config('configs/colley.yaml')
X_train = np.load("data/splits/colley/X_train.npy")
y_train = np.load("data/splits/colley/y_train.npy")
X_test = np.load("data/splits/colley/X_test.npy")
y_test = np.load("data/splits/colley/y_test.npy")

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
lr_probs = lr.predict_proba(X_test)[:,1]
lr_metrics = evaluate(lr_probs, y_test)
print(lr_metrics)
# Out:
# {'accuracy': 0.7611940298507462, 'auc': 0.8596569391846737, 'loss': 0.47148476585680954}

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_probs = rf.predict_proba(X_test)[:, 1]
rf_metrics = evaluate(rf_probs, y_test)
print(rf_metrics)
# Out:
# {'accuracy': 0.7686567164179104, 'auc': 0.8372688794831811, 'loss': 0.5208692777229568}

# %%
svm = SVC(probability=True, random_state=42)
svm.fit(X_train, y_train)
svm_probs = svm.predict_proba(X_test)[:, 1]
svm_metrics = evaluate(svm_probs, y_test)
print(svm_metrics)
# Out:
# {'accuracy': 0.746268656716418, 'auc': 0.813989752728893, 'loss': 0.5323653064205079}

# %%
nn_probs = get_nn_predictions(colley_config, X_test)
nn_metrics = evaluate(nn_probs, y_test)
print(nn_metrics)
# Out:
# {'accuracy': 0.7611940298507462, 'auc': 0.848741367787926, 'loss': 0.4800482599508624}

# %%
print(f'lr: {lr_metrics}, rf: {rf_metrics}, svm: {svm_metrics},  nn: {nn_metrics}')
# Out:
# lr: {'accuracy': 0.7611940298507462, 'auc': 0.8596569391846737, 'loss': 0.47148476585680954}, rf: {'accuracy': 0.7686567164179104, 'auc': 0.8372688794831811, 'loss': 0.5208692777229568}, svm: {'accuracy': 0.746268656716418, 'auc': 0.813989752728893, 'loss': 0.5323653064205079},  nn: {'accuracy': 0.7611940298507462, 'auc': 0.848741367787926, 'loss': 0.4800482599508624}

# %%
focal_config = load_config('configs/focal.yaml')
nn_probs = get_nn_predictions(focal_config, X_test)
nn_metrics = evaluate(nn_probs, y_test)
print(nn_metrics)
# Out:
# {'accuracy': 0.7611940298507462, 'auc': 0.8438404989975495, 'loss': 0.5636078962813648}
