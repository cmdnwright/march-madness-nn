# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from src.model.inference import get_nn_predictions
from src.training.evaluate import evaluate
from src.utils.config import load_config

# %%
config = load_config()
X_train = np.load("data/splits/baseline/X_train.npy")
y_train = np.load("data/splits/baseline/y_train.npy")
X_test = np.load("data/splits/baseline/X_test.npy")
y_test = np.load("data/splits/baseline/y_test.npy")

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
lr_probs = lr.predict_proba(X_test)[:,1]
lr_metrics = evaluate(lr_probs, y_test)
print(f'lr: {lr_metrics}')

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_probs = rf.predict_proba(X_test)[:, 1]
rf_metrics = evaluate(rf_probs, y_test)
print(f'rf: {rf_metrics}')

svm = SVC(probability=True, random_state=42)
svm.fit(X_train, y_train)
svm_probs = svm.predict_proba(X_test)[:, 1]
svm_metrics = evaluate(svm_probs, y_test)
print(f'SVM: {svm_metrics}')

nn_probs = get_nn_predictions(config, X_test)
nn_metrics = evaluate(nn_probs, y_test)
print(f'nn: {nn_metrics}')

print(f'lr: {lr_metrics}, rf: {rf_metrics}, svm: {svm_metrics},  nn: {nn_metrics}')

# %%
seed_preds = (X_test[:, -1] < 0).astype(int)
accuracy = float(np.mean(seed_preds == y_test))
print(accuracy)
# Out:
# 0.7835820895522388

# %%
colley_config = load_config('configs/colley.yaml')
X_train = np.load("data/splits/colley/X_train.npy")
y_train = np.load("data/splits/colley/y_train.npy")
X_test = np.load("data/splits/colley/X_test.npy")
y_test = np.load("data/splits/colley/y_test.npy")

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
lr_probs = lr.predict_proba(X_test)[:,1]
lr_metrics = evaluate(lr_probs, y_test)
print(f'lr: {lr_metrics}')

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_probs = rf.predict_proba(X_test)[:, 1]
rf_metrics = evaluate(rf_probs, y_test)
print(f'rf: {rf_metrics}')

svm = SVC(probability=True, random_state=42)
svm.fit(X_train, y_train)
svm_probs = svm.predict_proba(X_test)[:, 1]
svm_metrics = evaluate(svm_probs, y_test)
print(f'SVM: {svm_metrics}')

nn_probs = get_nn_predictions(colley_config, X_test)
nn_metrics = evaluate(nn_probs, y_test)
print(f'nn: {nn_metrics}')

print(f'lr: {lr_metrics}, rf: {rf_metrics}, svm: {svm_metrics},  nn: {nn_metrics}')

# %%
focal_config = load_config('configs/focal.yaml')
nn_probs = get_nn_predictions(focal_config, X_test)
nn_metrics = evaluate(nn_probs, y_test)
print(nn_metrics)
# Out:
# {'accuracy': 0.7761194029850746, 'auc': 0.8496324348407218, 'loss': 0.5255454752573648}

# %%
season_config = load_config('configs/season.yaml')
X_train = np.load("data/splits/colley-season/X_train.npy")
y_train = np.load("data/splits/colley-season/y_train.npy")
X_test = np.load("data/splits/colley-season/X_test.npy")
y_test = np.load("data/splits/colley-season/y_test.npy")

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
lr_probs = lr.predict_proba(X_test)[:,1]
lr_metrics = evaluate(lr_probs, y_test)
print(f'lr: {lr_metrics}')

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_probs = rf.predict_proba(X_test)[:, 1]
rf_metrics = evaluate(rf_probs, y_test)
print(f'rf: {rf_metrics}')

svm = SVC(probability=True, random_state=42)
svm.fit(X_train, y_train)
svm_probs = svm.predict_proba(X_test)[:, 1]
svm_metrics = evaluate(svm_probs, y_test)
print(f'SVM: {svm_metrics}')

nn_probs = get_nn_predictions(season_config, X_test)
nn_metrics = evaluate(nn_probs, y_test)
print(f'nn: {nn_metrics}')

print(f'lr: {lr_metrics}, rf: {rf_metrics}, svm: {svm_metrics},  nn: {nn_metrics}')
# Out:
# lr: {'accuracy': 0.7611940298507462, 'auc': 0.8596569391846737, 'loss': 0.47148476585677446}
# rf: {'accuracy': 0.7835820895522388, 'auc': 0.8331476943640009, 'loss': 0.5360101263166573}
# SVM: {'accuracy': 0.7313432835820896, 'auc': 0.7885943417242147, 'loss': 0.5642252261712686}
# nn: {'accuracy': 0.7611940298507462, 'auc': 0.8449543328135443, 'loss': 0.5059127819990404}
# lr: {'accuracy': 0.7611940298507462, 'auc': 0.8596569391846737, 'loss': 0.47148476585677446}, rf: {'accuracy': 0.7835820895522388, 'auc': 0.8331476943640009, 'loss': 0.5360101263166573}, svm: {'accuracy': 0.7313432835820896, 'auc': 0.7885943417242147, 'loss': 0.5642252261712686},  nn: {'accuracy': 0.7611940298507462, 'auc': 0.8449543328135443, 'loss': 0.5059127819990404}
